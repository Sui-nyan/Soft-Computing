# %%
import pandas as pd

df = pd.read_pickle("hyperneat_v1_winner.pkl")
df
# Out:
# {'winner': <neat.genome.DefaultGenome at 0x1a1cb2363d0>,
#  'experiment_config': {'environment': {'width': 800,
#    'height': 600,
#    'ship_radius': 15,
#    'ship_speed': 5.0,
#    'max_turn_rate': 0.2,
#    'fuel_capacity': 100.0,
#    'fuel_cost_per_thrust': 0.12,
#    'fuel_cost_per_step': 0.0,
#    'fuel_gain_per_mineral': 10.0,
#    'initial_minerals': 5,
#    'min_minerals': 3,
#    'mineral_radius': 10,
#    'asteroid_count': 8,
#    'asteroid_radius_min': 15,
#    'asteroid_radius_max': 30,
#    'asteroid_speed_min': 0.2,
#    'asteroid_speed_max': 2.0,
#    'max_steps': 1200,
#    'mine_threshold': 0.5,
#    'thrust_deadzone': 0.05,
#    'idle_thrust_threshold': 0.05,
#    'spawn_margin': 20,
#    'max_spawn_attempts': 100},
#   'grid': {'size': 9,
#    'view_radius': 280.0,
#    'mineral_signal_radius': 65.0,
#    'asteroid_signal_radius': 95.0},
#   'substrate': {'hidden_grid_size': 7,
#    'weight_threshold': 0.3,
#    'weight_scale': 3.0,
# ...
